# %%
import pandas as pd

# %%
CSV = "tracks2010-2021.csv"
tracks_df = pd.read_csv(CSV)
tracks_df.head()
# Out:
#                        id                                               name  \
# 0  6Pkt6qVikqPBt9bEQy8iTz                                 A Lover's Concerto
# 1  1hx7X9cMXHWJjknb9O6Ava  The September Of My Years - Live At The Sands ...
# 2  19oquvXf3bc65GSqtPYA5S  It Was A Very Good Year - Live At The Sands Ho...
# 3  55qyghODi24yaDgKBI6lx0  The Circle Game - Live at The 2nd Fret, Philad...
# 4  00xemFYjQNRpOlPhVaLAHa  Urge For Going - Live at The 2nd Fret, Philade...
#
#    popularity  duration_ms  explicit            artists  \
# 0          41       159560         0       ['The Toys']
# 1          26       187333         0  ['Frank Sinatra']
# 2          25       236800         0  ['Frank Sinatra']
# 3          18       313093         0  ['Joni Mitchell']
# 4          18       295093         0  ['Joni Mitchell']
#
#                    id_artists release_date  danceability  energy  key  \
# 0  ['6lH5PpuiMa5SpfjoIOlwCS']    3/13/2020         0.671   0.867    2
# ...

# %%
tracks_df['artists'].str.replace(r"['']","")
tracks_df['id_artists'].str.replace(r"['']","")
# Out:
# 0                                 [6lH5PpuiMa5SpfjoIOlwCS]
# 1                                 [1Mxqyy3pSjf8kZZL4QVxS0]
# 2                                 [1Mxqyy3pSjf8kZZL4QVxS0]
# 3                                 [5hW4L92KnC6dX9t7tYM4Ve]
# 4                                 [5hW4L92KnC6dX9t7tYM4Ve]
#                                 ...
# 121421                            [1QLBXKM5GCpyQQSVMNZqrZ]
# 121422                            [1dy5WNgIKQU6ezkpZs4y8z]
# 121423                            [37M5pPGs6V1fchFJSgCguX]
# 121424    [4jGPdu95icCKVF31CcFKbS, 5ebPSE9YI5aLeZ1Z2gkqjn]
# 121425                            [0i4Qda0k4nf7jnNHmSNpYv]
# Name: id_artists, Length: 121426, dtype: object

# %%
tracks_df.head()
# Out:
#                        id                                               name  \
# 0  6Pkt6qVikqPBt9bEQy8iTz                                 A Lover's Concerto
# 1  1hx7X9cMXHWJjknb9O6Ava  The September Of My Years - Live At The Sands ...
# 2  19oquvXf3bc65GSqtPYA5S  It Was A Very Good Year - Live At The Sands Ho...
# 3  55qyghODi24yaDgKBI6lx0  The Circle Game - Live at The 2nd Fret, Philad...
# 4  00xemFYjQNRpOlPhVaLAHa  Urge For Going - Live at The 2nd Fret, Philade...
#
#    popularity  duration_ms  explicit            artists  \
# 0          41       159560         0       ['The Toys']
# 1          26       187333         0  ['Frank Sinatra']
# 2          25       236800         0  ['Frank Sinatra']
# 3          18       313093         0  ['Joni Mitchell']
# 4          18       295093         0  ['Joni Mitchell']
#
#                    id_artists release_date  danceability  energy  key  \
# 0  ['6lH5PpuiMa5SpfjoIOlwCS']    3/13/2020         0.671   0.867    2
# ...

# %%
tracks_df.dtypes
# Out:
# id                   object
# name                 object
# popularity            int64
# duration_ms           int64
# explicit              int64
# artists              object
# id_artists           object
# release_date         object
# danceability        float64
# energy              float64
# key                   int64
# loudness            float64
# mode                  int64
# speechiness         float64
# acousticness        float64
# instrumentalness    float64
# liveness            float64
# valence             float64
# tempo               float64
# time_signature        int64
# dtype: object

# %%
tracks_clean_df = tracks_df.drop(columns=['artists', 'id_artists'])
tracks_clean_df.head()
# Out:
#                        id                                               name  \
# 0  6Pkt6qVikqPBt9bEQy8iTz                                 A Lover's Concerto
# 1  1hx7X9cMXHWJjknb9O6Ava  The September Of My Years - Live At The Sands ...
# 2  19oquvXf3bc65GSqtPYA5S  It Was A Very Good Year - Live At The Sands Ho...
# 3  55qyghODi24yaDgKBI6lx0  The Circle Game - Live at The 2nd Fret, Philad...
# 4  00xemFYjQNRpOlPhVaLAHa  Urge For Going - Live at The 2nd Fret, Philade...
#
#    popularity  duration_ms  explicit release_date  danceability  energy  key  \
# 0          41       159560         0    3/13/2020         0.671   0.867    2
# 1          26       187333         0     5/4/2018         0.319   0.201    7
# 2          25       236800         0     5/4/2018         0.269   0.129    7
# 3          18       313093         0   10/30/2020         0.644   0.212   11
# 4          18       295093         0   10/30/2020         0.627   0.184    1
#
# ...
