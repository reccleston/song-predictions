# %%
import pandas as pd

# %%
fullData = pd.read_csv('../data/fullDataUPDATE.csv')

# %%
fullData.columns
# Out:
# Index(['song', 'performer', 'chart_position', 'previous_position', 'peak',
#        'weeks_on_chart', 'hitTF', 'id', 'danceability', 'energy', 'key',
#        'loudness', 'mode', 'speechiness', 'acousticness', 'instrumentalness',
#        'liveness', 'valence', 'tempo', 'duration_ms', 'time_signature'],
#       dtype='object')

# %%
fullData[fullData['previous_position'] == '-']
# Out:
#                       song      performer  chart_position previous_position  \
# 651           Clear Da Air   Moneybagg Yo           100.0                 -
# 652          Country Again   Thomas Rhett            73.0                 -
# 655          Final Warning     NLE Choppa            90.0                 -
# 665  How They Remember You  Rascal Flatts            89.0                 -
# 667           Just Say Det   Moneybagg Yo            82.0                 -
# 678  Single Saturday Night  Cole Swindell            95.0                 -
# 682                  Tampa         Cico P            97.0                 -
# 695             Your Power  Billie Eilish            10.0                 -
#
#       peak  weeks_on_chart  hitTF                      id  danceability  \
# 651  100.0             1.0    1.0  6YkP0P7VPAENzoRjy8ojV2         0.818
# 652   73.0             1.0    1.0  3CiF9D8iuVhZWDvvjf8HpG         0.467
# ...

# %%
fullData['previous_position'] = fullData['previous_position'].replace(['-'], 0)

# %%
fullData[fullData['previous_position'] == '-']
# Out:
# Empty DataFrame
# Columns: [song, performer, chart_position, previous_position, peak, weeks_on_chart, hitTF, id, danceability, energy, key, loudness, mode, speechiness, acousticness, instrumentalness, liveness, valence, tempo, duration_ms, time_signature]
# Index: []
#
# [0 rows x 21 columns]

# %%
fullData.dtypes
# Out:
# song                  object
# performer             object
# chart_position       float64
# previous_position     object
# peak                 float64
# weeks_on_chart       float64
# hitTF                float64
# id                    object
# danceability         float64
# energy               float64
# key                  float64
# loudness             float64
# mode                 float64
# speechiness          float64
# acousticness         float64
# instrumentalness     float64
# liveness             float64
# valence              float64
# tempo                float64
# duration_ms          float64
# time_signature       float64
# dtype: object

# %%
# changing datatype of previous position
fullData['previous_position'] = pd.to_numeric(fullData['previous_position'], downcast="float")

# %%
fullData.dtypes
# Out:
# song                  object
# performer             object
# chart_position       float64
# previous_position    float32
# peak                 float64
# weeks_on_chart       float64
# hitTF                float64
# id                    object
# danceability         float64
# energy               float64
# key                  float64
# loudness             float64
# mode                 float64
# speechiness          float64
# acousticness         float64
# instrumentalness     float64
# liveness             float64
# valence              float64
# tempo                float64
# duration_ms          float64
# time_signature       float64
# dtype: object

# %%
fullData.to_csv('../data/fullDataUPDATE.csv')
